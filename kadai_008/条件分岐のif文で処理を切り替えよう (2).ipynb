# %%
var = 15

# 変数varが、3の倍数の場合は「Fizz」を出力
if  (var%3) == 0:
    print("Fizz")

# 変数varが、5の倍数の場合は「Buzz」を出力
if (var%5) == 0:
    print("Buzz")

#・変数varが、3の倍数と5の倍数の両方に該当する場合は「FizzBuzz」を出力
if (var%3) == 0 and (var%5) ==0:
   print("FizzBuzz")

else:
  print(var)
# Out:
# Fizz
# Buzz
# FizzBuzz

# %%
#修正したコードを記載いたします。よろしくお願いいたします(24.11.28)

var = 15
if (var%3) == 0 and (var%5) ==0:
  print("FizzBuzz")
elif (var%3) == 0:
  print("Fizz")
elif (var%5) == 0:
  print("Buzz")
else:
  print(var)
# Out:
# FizzBuzz
