# %%
def total():
  price1 = 100
  price2 = 200
  tax = 1.1
  return price1 + price2

print (total() *tax 1.1)
# Out:
#   File "<ipython-input-6-0fa2f24338cd>", line 7
#     print (total() *tax 1.1)
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
